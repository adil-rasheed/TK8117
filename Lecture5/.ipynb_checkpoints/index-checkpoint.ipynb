# %% [markdown]
# # Course material
#
# * [Linear Regression](LinearRegression.ipynb)
#
# * [Logistic Regression](BinaryClassLogisticRegression.ipynb)
#
# * [Decision Tree](PCA_Residuals.ipynb)
#
# * [Bonus: SVM](svm.ipynb)
# 
# * [NIPALS algorithm for PLS](PCA-Cylinder.ipynb)
